# %%
import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("torchvision version:", torchvision.__version__)

# # PyTorch 및 GPU 사용 여부 확인
# import torch 
# if not torch.cuda.is_available(): 
#     print('GPU not available.')
# Out:
# PyTorch version: 2.0.1
# torchvision version: 0.15.2

# %%
# DeOldify 관련 라이브러리
import fastai 
from deoldify.visualize import *
import warnings
# Out:
# NumExpr defaulting to 8 threads.

# %%
# 경고 메시지 무시
warnings.filterwarnings("ignore", category=UserWarning, message=".*?Your .*? set is empty.*?")

# %%
# DeOldify 모델 로드 (artistic 모드 사용)
colorizer = get_image_colorizer(artistic=True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# 컬러화할 이미지 URL
source_url = 'https://img.hankyung.com/photo/202108/BF.27178814.1.jpg'

# %%
# 렌더링 품질 (값이 클수록 품질이 높지만 처리 속도가 느려짐)
render_factor = 39

# %%
# 워터마크 추가 여부
watermarked = False

# %%
# 컬러화 수행 및 결과 저장
if source_url is not None and source_url != '':
    image_path = colorizer.plot_transformed_image_from_url(
        url=source_url, 
        render_factor=render_factor, 
        compare=True, 
        watermarked=watermarked
    )
    # 결과 표시
    show_image_in_notebook(image_path)
else:
    print('Provide a valid image URL.')
